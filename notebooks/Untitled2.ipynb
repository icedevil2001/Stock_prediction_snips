# %%
from bs4 import BeautifulSoup

# %%
import urllib
import pandas as pd

# %%
from bs4 import BeautifulSoup
import requests

# url="https://en.wikipedia.org/wiki/List_of_countries_by_GDP_(nominal)"
url = "https://electric-scooter.guide/comparisons/compare-electric-scooters/"

# Make a GET request to fetch the raw HTML content
html_content = requests.get(url)
print(html_content)
# Parse the html content
soup = BeautifulSoup(html_content, "html")
# print(soup.prettify()) # print the parsed data of html
# Out:
# <Response [403]>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-f8acbf14013f> in <module>()
#       9 print(html_content)
#      10 # Parse the html content
# ---> 11 soup = BeautifulSoup(html_content, "html")
#      12 # print(soup.prettify()) # print the parsed data of html
#
# /Users/icedevil2001/miniconda3/lib/python2.7/site-packages/bs4/__init__.pyc in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, **kwargs)
#     265         if hasattr(markup, 'read'):        # It's a file-type object.
#     266             markup = markup.read()
# --> 267         elif len(markup) <= 256 and (
#     268                 (isinstance(markup, bytes) and not b'<' in markup)
#     269                 or (isinstance(markup, unicode) and not u'<' in markup)
#
# TypeError: object of type 'Response' has no len()

# %%
gdp_table = soup.find("table", attrs={"class": "wikitable"})
gdp_table_data = gdp_table.tbody.find_all("tr")  # contains 2 rows

# Get all the headings of Lists
headings = []
for td in gdp_table_data[0].find_all("td"):
    # remove any newlines and extra spaces from left and right
    headings.append(td.b.text.replace('\n', ' ').strip())

print(headings)
# Out:
# [u'Per the International Monetary Fund (2019 estimates)', u'Per the World Bank (2019)', u'Per the United Nations (2018)']

# %%
t ='''Inokim	Mini 2	
748	17	24	16	165	6	37	15	12	250	281	None	Foot	Mixed	None	None
  	Kaabo	Air	
399	17	24	19	0	8	38	6	12	350	281	None	Foot	Solid	Both	None
  	Macwheel	MX2	
320	12	24	15	220	8	43	19	16	300	180	None	Foot	Solid	None	None
  	Segway	Ninebot ES1	
523	16	24	12	220	8	44	17	12	250	187	None	Foot	Solid	None	IP54
  	UScooters	Booster Sport	
899	20	24	25	279	7	37	5	12	500	314	Both	Foot	Solid	Both	None
  	UScooters	Booster V	
1049	24	24	25	279	7	37	5	12	500	378	Both	Foot	Solid	Both	None
  	UScooters	Eco	
499	16	24	15	249	7	37	5	12	350	156	Both	Foot	Solid	Both	None
  	E-TWOW	GT	
999	23	26	25	220	7	45	6	13	700	504	Both	Foot	Solid	Both	None
  	GOTRAX	GXL Commuter v2	
248	12	26	16	220	8	39	17	14	250	187	None	Disc	Pneumatic	None	IP54
  	GOTRAX	Xr	
299	12	26	16	220	8	41	15	6	250	187	Both	Disc	Pneumatic	None	IP54
  	GOTRAX	Xr Ultra	
349	16	26	16	220	8	41	15	6	300	252	Both	Disc	Pneumatic	None	IP54
  	Levy Electric	Levy	
499	15	26	18	229	8	41	17	17	350	230	Both	Disc	Pneumatic	None	IP54
  	Macwheel	MX3	
350	17	26	16	264	8	0	0	0	350	270	Both	Foot	Solid	Both	None
  	MegaWheels	S10	
299	14	26	16	220	8	42	17	17	250	270	Both	Foot	Mixed	None	None
  	Swagtron	Swagger 5	
299	12	26	18	319	8	45	17	19	250	216	Both	Disc	Mixed	None	IPX4
  	Unagi	Model One (E500)	
990	16	26	16	275	7	37	16	15	500	282	Both	Electronic	Solid	None	IP54
  	Xiaomi	Mi M365	
400	19	26	16	220	8	42	17	19	250	280	Both	Disc	Pneumatic	None	IP54
  	E-TWOW	GT 2020	
1089	31	26	25	220	7	45	6	13	700	504	Both	Drum	Solid	Both	None
  	GOTRAX	Xr Elite	
399	18	26	16	220	8	41	15	6	300	281	Both	Disc	Pneumatic	None	IP54
  	Fluid Freeride	CityRider	
399	10	29	18	220	8	43	18	20	300	270	Both	Drum	Solid	None	None
  	Glion	Dolly	
500	16	29	16	255	8	37	8	12	250	238	None	Electronic	Solid	None	None
  	Hiboy	S2	
429	17	29	19	264	8	45	16	19	350	270	Both	Disc	Solid	None	IPX4
  	Macwheel	MX1	
369	19	29	16	264	8	43	19	16	350	270	Both	Disc	Solid	None	None
  	Segway	Ninebot ES2	
589	16	29	16	220	8	44	17	12	300	187	Both	Foot	Solid	Both	IP54
  	Swagtron	Swagger 7	
500	8	29	16	264	8	0	0	0	350	230	Both	Disc	Pneumatic	None	IPX4
  	TurboAnt	X7	
399	16	29	20	275	8	41	16	18	350	230	Both	Disc	Pneumatic	None	IPX4
  	UScooters	Booster GT	
1089	31	29	25	275	7	45	6	13	700	504	Both	Foot	Solid	Both	None
  	Inokim	Light 2	
1199	25	31	16	220	8	37	10	14	350	374	Both	Drum	Pneumatic	None	None
  	Levy Electric	Levy Plus	
699	22	31	18	229	10	41	17	17	350	374	Both	Disc	Pneumatic	None	IP54
  	Segway	Ninebot ES4	
699	28	31	19	220	8	44	17	12	300	374	Both	Foot	Solid	Both	IP54
  	Xiaomi	M365 Pro	
680	28	31	16	220	8	44	17	19	300	474	Both	Disc	Pneumatic	None	IP54
  	Hiboy	MAX	
399	17	33	19	220	8	44	19	16	350	270	Both	Disc	Solid	None	IPX4
  	Inokim	Quick 3 Hero	
1268	19	33	17	264	10	43	9	10	250	374	Both	Disc	Pneumatic	None	None
  	Joyor	X5S	
1145	31	33	22	264	10	41	7	15	500	624	Both	Disc	Pneumatic	None	None
  	Kaabo	Skywalker 8H	
649	25	33	24	264	8	39	7	13	500	624	Both	Drum	Solid	Both	None
  	Magnum bikes	I-MAX S1+	
1299	20	35	20	528	10	37	5	12	500	480	Both	Disc	Pneumatic	None	None
  	Inokim	Quick 3 Super +	
1440	28	37	19	264	10	43	9	10	450	624	None	Disc	Pneumatic	None	None
  	Kaabo	Skywalker 8H	
549	17	37	21	264	8	39	7	13	350	374	Both	Drum	Solid	Both	None
  	Apollo	Light	
749	22	37	22	220	8	39	7	16	350	490	Both	Drum	Mixed	Both	IP54
  	EMOVE	Touring	
899	24	40	25	330	8	43	7	10	500	624	Both	Drum	Mixed	Both	None
  	EVOLV	City	
817	25	40	22	264	8	39	7	14	350	374	Both	Drum	Mixed	Both	None
  	EVOLV	Tour 2.0	
1100	25	40	28	264	10	48	9	15	600	624	Both	Disc	Pneumatic	Both	IP54
  	Fluid Freeride	Horizon	
699	20	40	25	264	8	38	7	14	500	499	Both	Drum	Mixed	Both	None
  	Mercane	WideWheel (Single)	
899	19	40	15	220	8	43	9	16	500	422	Both	Disc	Solid	Both	IPX4
  	Turbowheel	Dart	
998	30	40	25	220	9	43	8	15	600	614	Both	Disc	Pneumatic	Both	None
  	Turbowheel	Swift	
799	25	40	25	220	8	39	7	14	500	614	Both	Drum	Mixed	Both	None
  	Zero	8	
799	22	40	22	220	8	39	7	14	500	624	Both	Drum	Mixed	Both	None
  	Zero	9	
1100	28	40	28	220	8	43	7	14	600	624	Both	Disc	Pneumatic	Both	None
  	Apollo	City	
999	28	40	28	264	8	43	8	14	600	634	Both	Disc	Pneumatic	Both	IP54
  	Fluid Freeride	Horizon (13 Ah)	
799	25	42	25	264	8	38	7	14	500	624	Both	Drum	Mixed	Both	None
  	Segway	Ninebot Max	
799	40	42	19	220	10	46	18	21	350	551	Both	Drum	Pneumatic	None	IPX5
  	Mercane	WideWheel (Dual)	
999	31	44	20	220	8	43	9	16	1000	634	Both	Disc	Solid	Both	IPX4
  	Minimotors	Dualtron Spider	
2450	37	44	40	264	10	44	9	19	1320	1050	Both	Disc	Pneumatic	Both	None
  	Boosted	Rev	
1599	22	46	24	249	9	44	24	20	1500	370	Both	Disc	Pneumatic	None	IP67
  	Kaabo	Skywalker 10H	
899	31	46	26	264	10	46	9	13	800	749	Both	Disc	Pneumatic	Both	None
  	Kaabo	Skywalker 8S	
849	25	48	25	264	8	39	7	13	800	624	Both	Disc	Solid	Both	None
  	EVOLV	Tour XL	
1173	25	48	28	264	10	48	9	15	600	624	Both	Disc	Pneumatic	Both	None
  	EVOLV	Tour XL Plus	
1284	34	51	28	264	10	48	9	15	600	874	Both	Disc	Pneumatic	Both	None
  	Mercane	WideWheel Pro	
1149	35	53	26	220	8	43	9	16	1000	720	Both	Disc	Solid	Both	IP54
  	Turbowheel	Pacer	
1499	40	53	30	279	10	45	9	15	1000	1156	Both	Disc	Pneumatic	Both	None
  	Zero	10	
1259	40	53	30	264	10	46	9	17	1000	936	Both	Disc	Pneumatic	Both	None
  	Apollo	Explore	
1299	37	53	31	264	10	46	9	17	1000	946	Both	Disc	Pneumatic	Both	IP54
  	Inmotion	L9	
899	59	53	19	330	10	51	20	22	1000	675	Both	Disc	Pneumatic	Both	IP55
  	EMOVE	Cruiser	
1399	62	55	28	352	10	48	10	16	600	1560	Both	Disc	Pneumatic	Both	IP67
  	Inokim	OX	
1300	34	55	22	264	10	47	23	23	700	624	Both	Disc	Pneumatic	Both	None
  	Kaabo	Skywalker 10S	
1150	43	55	31	264	10	46	9	13	1200	936	Both	Disc	Pneumatic	Both	None
  	Qiewa	Q1 Hummer	
1399	60	55	35	550	10	43	0	15	800	1248	Both	Disc	Pneumatic	Both	IP65
  	Turbowheel	Hornet	
1549	37	57	28	299	8	45	9	15	1000	921	Both	Disc	Solid	Both	None
  	Mercane	MX60	
1962	62	59	37	264	11	50	15	21	2400	1200	Both	Disc	Pneumatic	Both	None
  	Inokim	OX (Super)	
1770	62	62	28	264	10	48	23	21	800	1210	Both	Disc	Pneumatic	Both	None
  	Kaabo	Mantis	
